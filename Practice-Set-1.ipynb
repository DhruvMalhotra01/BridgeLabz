# %% [markdown]
# 1. ATM Transaction Validator

# %%
# Withdrawal amount must be a multiple of 100
# Account balance must never go negative
# For each transaction, print SUCCESS or FAILED


money = int(input())
n= int(input())  #number of transactions

transactions = []

for _ in  range(n):
    transactions.append(int(input()))

for transaction in transactions:
    if transaction % 100 == 0 and money - transaction >= 0:
        money -= transaction
        print("SUCCESS")
    else:
        print("FAILED")

print(money)
# Out:
# SUCCESS
# FAILED
# SUCCESS
# FAILED
# 1800

# %% [markdown]
# 2. Smart Electricity Billing

# %%
# Electricity bill is calculated slab-wise:
# ● First 100 units → ₹3/unit
# ● Next 100 units → ₹5/unit
# ● Remaining → ₹8/unit

# If usage > 300 units, add 10% surcharge.



units = int(input())

if units <= 100:
    bill = units * 3

elif units <= 200:
    bill = 100 * 3 + (units - 100) * 5

else:
    bill = 100 * 3 + 100 * 5 + (units - 200) * 8


    
print(int(bill * 1.1) if units > 300 else int(bill))
# Out:
# 2200

# %% [markdown]
# 3. Password Strength Evaluator

# %%
# Given a password string:
# ● Must contain at least 1 digit
# ● Must contain at least 1 uppercase
# ● Length ≥ 8

s = input()

a = (any(ch.isdigit() for ch in s))
b = (any(ch.isupper() for ch in s))
c = (any(ch.islower() for ch in s))
d = (len(s) >= 8)

print("Strong" if a and b and c and d else "Weak")
# Out:
# Weak

# %% [markdown]
# 4. Traffic Signal Simulator

# %%
n = int(input())

if n <= 30:
    print("RED")
elif n <= 45:
    print("YELLOW")
elif n <= 90:
    print("GREEN")
else:
    print("INVALID")
# Out:
# INVALID

# %% [markdown]
# 5. Salary Deductoin System

# %%
salary = int(input())
late_days = int(input())
absent_days = int(input())
deduction = 0
if (late_days > 10):
    deduction += 0.10 * salary
elif (late_days > 5):
    deduction += 0.05 * salary

if (absent_days > 2):
    deduction += 0.05 * salary

print(int(salary - deduction))
# Out:
# 47500

# %% [markdown]
# 6. Prime Range Analyzer

# %%
# prime number between A and B
a  = int(input())
b = int(input())

def isPrime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False;
    return True;

count = 0
for i in range(a,b+1):
    if isPrime(i):
        count +=1



print(count)
# Out:
# 6

# %% [markdown]
# 7️. Online Order Discount Engine

# %%
amount = int(input())

if amount >= 5000:
    print(int(amount * 0.8))
elif amount >= 3000:
    print(int(amount * 0.9))
elif amount >= 1000:
    print(int(amount * 0.95))
else:
    print(int(amount))
# Out:
# 2880

# %% [markdown]
# 8️. Binary to Decimal Converter (Without Built-in)

# %%
binary = input("Enter the binary number : ")

# try:
decimal = int(binary,2)
print(decimal)
# except ValueError:
#     print("Invalid binary number")
# Out:
# 45

# %% [markdown]
# 9. Mobile battery Drain

# %%
d= int(input("Enter value : "))

battery = 100
minutes = 0

while battery > 0:
    battery -= d
    minutes += 1

print(minutes)
# Out:
# 15

# %% [markdown]
# 10. Exam Result Processor

# %%
marks = list(map(int, input().split()))

if any(mark < 35 for mark in marks):
    print("FAIL")
elif sum(marks) / len(marks) >= 75:
    print("DISTINCTION")
else:
    print("PASS")
# Out:
# DISTINCTION

# %% [markdown]
# 11. Number Compression Counter

# %%
n = int(input())
count = 0

while(n%2 == 0):
    n //= 2  # devide answer remain integer 
    count += 1

print(count)
# Out:
# 3

# %% [markdown]
# 12️. Vowel Frequency Analyzer

# %%
sentence = input()
count = 0
sum(ch in "aeiouAEIOU" for ch in s)
